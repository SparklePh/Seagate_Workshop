# %%
# !git clone https://github.com/SparklePh/Seagate_Workshop
# Out:
# Cloning into 'Seagate_Workshop'...
# remote: Enumerating objects: 2708, done.
# remote: Total 2708 (delta 0), reused 0 (delta 0), pack-reused 2708 (from 2)
# Receiving objects: 100% (2708/2708), 221.68 MiB | 16.18 MiB/s, done.
# Resolving deltas: 100% (26/26), done.
# Updating files: 100% (6117/6117), done.

# %%
# %cd /content/Seagate_Workshop
# Out:
# /content/Seagate_Workshop

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 14.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Download data

# %%
import torch

# Is CUDA available?
print("CUDA available:", torch.cuda.is_available())

# Current device index
print("Current device:", torch.cuda.current_device())

# Name of the GPU
if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(torch.cuda.current_device()))

# Number of GPUs
print("Number of GPUs:", torch.cuda.device_count())

# CUDA version PyTorch was built with
print("CUDA version:", torch.version.cuda)
# Out:
# CUDA available: True
# Current device: 0
# GPU name: Tesla T4
# Number of GPUs: 1
# CUDA version: 12.8

# %% [markdown]
# # ตรงนี้แก้จากที่สอนให้ Save เครื่อง colab เลยเพราะบ้างคน Dive เต็ม

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8l.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data=f"data/cars_data/data.yaml", epochs=5, imgsz=640, device=0)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# YOLOv8l summary: 209 layers, 43,691,520 parameters, 0 gradients, 165.7 GFLOPs
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # หา path ที่ results save ออกมา แล้วลอง run เทียบกับ model ที่มีมาแล้วใน model/yolov8l_car.pt

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/content/Seagate_Workshop/model/yolov8l_car.pt")
# model = YOLO("runs/detect/train/weights/yolov8l.pt")

# Run inference on a video with a confidence threshold
results = model(
    "/content/Seagate_Workshop/data/highway.mp4",   # input video
    save=True,            # save the output video
    show=True,            # display inline
    conf=0.5,             # show predictions with confidence
)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/812) /content/Seagate_Workshop/data/highway.mp4: 384x640 3 cars, 1 truck, 52.7ms
# video 1/1 (frame 2/812) /content/Seagate_Workshop/data/highway.mp4: 384x640 3 cars, 1 truck, 39.7ms
# video 1/1 (frame 3/812) /content/Seagate_Workshop/data/highway.mp4: 384x640 3 cars, 1 truck, 38.9ms
# ...

# %%
INPUT_VIDEO =  "/content/Seagate_Workshop/runs/detect/predict/highway.avi"
OUT_VIDEO = "/content/Seagate_Workshop/runs/detect/predict/highway.mp4"

# !ffmpeg -i  {INPUT_VIDEO} -vcodec libx264 {OUT_VIDEO}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML, display
from base64 import b64encode

video_path_output = "/content/Seagate_Workshop/runs/detect/predict/highway.mp4"

mp4 = open(video_path_output,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# Use file path directly
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
